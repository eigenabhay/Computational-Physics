# %%
import numpy as np

def jacobi(A, b, max_iterations=100, tol=0.001):
    n = len(A)
    x = np.zeros(n)
    x_new = np.zeros(n)
    for iteration in range(1, max_iterations + 1):
        for i in range(n):
            x_new[i] = (b[i] - np.dot(A[i, :i], x[:i]) - np.dot(A[i, i+1:], x[i+1:])) / A[i, i]
        if np.max(np.abs(x_new - x)) < tol:
            break
        x = np.copy(x_new)
        print(f"Iteration {iteration}: {x}")
    return x

# Define the matrices A and vectors b
A1 = np.array([[3, -1, 1], [3, 6, 2], [3, 3, 7]])
b1 = np.array([1, 0, 4])

# Solve the system using the Jacobi method and print the improved solution after each iteration
x1 = jacobi(A1, b1)
print("Final solution to A1x = b1:", x1)
print()

A2 = np.array([[10, -1, 0], [-1, 10, -2], [0, -2, 10]])
b2 = np.array([9, 7, 6])
x2 = jacobi(A2, b2)
print("Solution to A2x = b2:", x2)
print()

A3 = np.array([[10, 5, 0, 0], [5, 10, -4, 0], [0, -4, 8, -1], [0, 0, -1, 5]])
b3 = np.array([6, 25, -11, -11])
x3 = jacobi(A3, b3)
print("Solution to A3x = b3:", x3)
print()

A4 = np.array([[4, 1, 1, 0, 1], [-1, -3, 1, 1, 0], [2, 1, 5, -1, -1], [-1, -1, -1, 4, 0], [0, 2, -1, 1, 4]])
b4 = np.array([6, 6, 6, 6, 6])
x4 = jacobi(A4, b4)
print("Solution to A4x = b4:", x4)
print()
# Out:
# Iteration 1: [0.33333333 0.         0.57142857]
# Iteration 2: [ 0.14285714 -0.35714286  0.42857143]
# Iteration 3: [ 0.07142857 -0.21428571  0.66326531]
# Iteration 4: [ 0.04081633 -0.25680272  0.63265306]
# Iteration 5: [ 0.03684807 -0.23129252  0.66399417]
# Iteration 6: [ 0.03490444 -0.23975543  0.6547619 ]
# Iteration 7: [ 0.03516089 -0.23570619  0.65922185]
# Iteration 8: [ 0.03502399 -0.23732106  0.65737656]
# Final solution to A1x = b1: [ 0.03502399 -0.23732106  0.65737656]
#
# Iteration 1: [0.9 0.7 0.6]
# Iteration 2: [0.97 0.91 0.74]
# Iteration 3: [0.991 0.945 0.782]
# Iteration 4: [0.9945 0.9555 0.789 ]
# Iteration 5: [0.99555 0.95725 0.7911 ]
# Solution to A2x = b2: [0.99555 0.95725 0.7911 ]
#
# Iteration 1: [ 0.6    2.5   -1.375 -2.2  ]
# Iteration 2: [-0.65   1.65  -0.4   -2.475]
# Iteration 3: [-0.225     2.665    -0.859375 -2.28    ]
# Iteration 4: [-0.7325    2.26875  -0.3275   -2.371875]
# Iteration 5: [-0.534375    2.73525    -0.53710938 -2.2655    ]
# Iteration 6: [-0.767625    2.55234375 -0.2905625  -2.30742188]
# Iteration 7: [-0.67617187  2.7675875  -0.38725586 -2.2581125 ]
# Iteration 8: [-0.78379375  2.68318359 -0.27347031 -2.27745117]
# Iteration 9: [-0.7415918   2.78250875 -0.3180896  -2.25469406]
# Iteration 10: [-0.79125438  2.74356006 -0.26558238 -2.26361792]
# Iteration 11: [-0.77178003  2.78939423 -0.28617221 -2.25311648]
# Iteration 12: [-0.79469712  2.77142113 -0.26194244 -2.25723444]
# Iteration 13: [-0.78571057  2.79257158 -0.27144374 -2.25238849]
# Iteration 14: [-0.79628579  2.78427779 -0.26026277 -2.25428875]
# Iteration 15: [-0.79213889  2.79403779 -0.2646472  -2.25205255]
# Iteration 16: [-0.79701889  2.79021057 -0.25948768 -2.25292944]
# Iteration 17: [-0.79510528  2.79471438 -0.2615109  -2.25189754]
# Iteration 18: [-0.79735719  2.79294828 -0.25913    -2.25230218]
# Iteration 19: [-0.79647414  2.79502659 -0.26006363 -2.251826  ]
# Iteration 20: [-0.7975133   2.79421162 -0.25896495 -2.25201273]
# Solution to A3x = b3: [-0.7975133   2.79421162 -0.25896495 -2.25201273]
#
# Iteration 1: [ 1.5 -2.   1.2  1.5  1.5]
# Iteration 2: [ 1.325 -1.6    1.6    1.675  2.425]
# Iteration 3: [ 0.89375 -1.35     1.81     1.83125  2.28125]
# Iteration 4: [ 0.8146875  -1.08416667  1.935       1.8384375   2.1696875 ]
# Iteration 5: [ 0.74486979 -1.01375     1.89258333  1.91638021  2.06622396]
# Iteration 6: [ 0.76373568 -0.97863542  1.90132292  1.90592578  2.00092578]
# Iteration 7: [ 0.76909668 -0.98549566  1.87160313  1.92160579  1.98816699]
# Iteration 8: [ 0.78143139 -0.99196259  1.87141502  1.91380104  1.98024716]
# Iteration 9: [ 0.7850751  -0.99873844  1.8646296   1.91522095  1.98538479]
# Iteration 10: [ 0.78718101 -1.00174151  1.8658388   1.91274157  1.98672138]
# Iteration 11: [ 0.78729533 -1.00286688  1.86536849  1.91281957  1.98914507]
# Solution to A4x = b4: [ 0.78729533 -1.00286688  1.86536849  1.91281957  1.98914507]

# %%
a = np.array([1, 0, 3, -2])
b = np.array([0, -2, -1, 3])

print(np.linalg.norm(a - b))
print(np.max(np.abs(a - b)))
print(np.abs(a - b))
